# %% [markdown]
# <a href="https://colab.research.google.com/github/MathewLipman/Work-Samples/blob/main/Exchange_rate_charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

exchange_rates = pd.read_csv('/content/drive/MyDrive/Dataset/euro-daily-hist_1999_2022.csv')
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2023-04-18               1.6276           1.9558            5.3899
# 1   2023-04-17               1.6356           1.9558            5.3861
# 2   2023-04-14               1.6309           1.9558            5.4410
# 3   2023-04-13               1.6343           1.9558            5.4117
# 4   2023-04-12               1.6377           1.9558            5.4635
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.4679         0.9831                   7.5436              NaN
# 1             1.4673         0.9812                   7.5433              NaN
# 2             1.4725         0.9827                   7.5761              NaN
# 3             1.4759         0.9804                   7.5758              NaN
# 4             1.4728         0.9853                   7.5183              NaN
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# 0          23.373          7.4513  ...          4.9357               NaN
# 1          23.345          7.4520  ...          4.9425               NaN
# 2          23.341          7.4510  ...          4.9423               NaN
# 3          23.271          7.4509  ...          4.9435               NaN
# 4          23.421          7.4506  ...          4.9385               NaN
#
#   [Swedish krona ] [Singapore dollar ] [Slovenian tolar ] [Slovak koruna ]  \
# 0          11.2955              1.4614                NaN              NaN
# 1          11.3163              1.4615                NaN              NaN
# 2          11.3455              1.4665                NaN              NaN
# 3          11.3886              1.4592                NaN              NaN
# 4          11.3480              1.4538                NaN              NaN
#
#   [Thai baht ] [Turkish lira ] [US dollar ]  [South African rand ]
# 0      37.6230         21.2812       1.0972                19.9299
# 1      37.7530         21.2835       1.0981                19.8937
# 2      37.6600         21.4218       1.1057                19.9352
# 3      37.5480         21.2912       1.1015                19.9710
# 4      37.3910         21.0976       1.0922                20.1330
#
# [5 rows x 41 columns]

# %%
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 6279   1999-01-08               1.8406              NaN               NaN
# 6280   1999-01-07               1.8474              NaN               NaN
# 6281   1999-01-06               1.8820              NaN               NaN
# 6282   1999-01-05               1.8944              NaN               NaN
# 6283   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 6279             1.7643         1.6138                      NaN
# 6280             1.7602         1.6165                      NaN
# 6281             1.7711         1.6116                      NaN
# 6282             1.7965         1.6123                      NaN
# 6283             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]  ... [Romanian leu ]  \
# 6279          0.58187          34.938          7.4433  ...          1.3143
# 6280          0.58187          34.886          7.4431  ...          1.3092
# 6281          0.58200          34.850          7.4452  ...          1.3168
# 6282          0.58230          34.917          7.4495  ...          1.3168
# 6283          0.58231          35.107          7.4501  ...          1.3111
#
#      [Russian rouble ] [Swedish krona ] [Singapore dollar ]  \
# 6279           27.2075           9.1650              1.9537
# 6280           26.9876           9.1800              1.9436
# 6281           27.4315           9.3050              1.9699
# 6282           26.5876           9.4025              1.9655
# 6283           25.2875           9.4696              1.9554
#
#      [Slovenian tolar ] [Slovak koruna ] [Thai baht ] [Turkish lira ]  \
# 6279           188.8400           42.560      42.5590          0.3718
# 6280           188.8000           42.765      42.1678          0.3701
# 6281           188.7000           42.778      42.6949          0.3722
# 6282           188.7750           42.848      42.5048          0.3728
# 6283           189.0450           42.991      42.6799          0.3723
#
#      [US dollar ]  [South African rand ]
# 6279       1.1659                 6.7855
# 6280       1.1632                 6.8283
# 6281       1.1743                 6.7307
# 6282       1.1790                 6.7975
# 6283       1.1789                 6.9358
#
# [5 rows x 41 columns]

# %%
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6284 entries, 0 to 6283
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Period\Unit:              6284 non-null   object
#  1   [Australian dollar ]      6284 non-null   object
#  2   [Bulgarian lev ]          5882 non-null   object
#  3   [Brazilian real ]         6016 non-null   object
#  4   [Canadian dollar ]        6284 non-null   object
#  5   [Swiss franc ]            6284 non-null   object
#  6   [Chinese yuan renminbi ]  6016 non-null   object
#  7   [Cypriot pound ]          2346 non-null   object
#  8   [Czech koruna ]           6284 non-null   object
#  9   [Danish krone ]           6284 non-null   object
#  10  [Estonian kroon ]         3130 non-null   object
#  11  [UK pound sterling ]      6284 non-null   object
#  12  [Greek drachma ]          520 non-null    object
#  13  [Hong Kong dollar ]       6284 non-null   object
#  14  [Croatian kuna ]          5941 non-null   object
#  15  [Hungarian forint ]       6284 non-null   object
#  16  [Indonesian rupiah ]      6284 non-null   object
#  17  [Israeli shekel ]         6016 non-null   object
#  18  [Indian rupee ]           6016 non-null   object
#  19  [Iceland krona ]          3877 non-null   float64
#  20  [Japanese yen ]           6284 non-null   object
#  21  [Korean won ]             6284 non-null   object
#  22  [Lithuanian litas ]       4159 non-null   object
#  23  [Latvian lats ]           3904 non-null   object
#  24  [Maltese lira ]           2346 non-null   object
#  25  [Mexican peso ]           6284 non-null   object
#  26  [Malaysian ringgit ]      6284 non-null   object
#  27  [Norwegian krone ]        6284 non-null   object
#  28  [New Zealand dollar ]     6284 non-null   object
#  29  [Philippine peso ]        6284 non-null   object
#  30  [Polish zloty ]           6284 non-null   object
#  31  [Romanian leu ]           6222 non-null   float64
#  32  [Russian rouble ]         5994 non-null   object
#  33  [Swedish krona ]          6284 non-null   object
#  34  [Singapore dollar ]       6284 non-null   object
#  35  [Slovenian tolar ]        2085 non-null   object
#  36  [Slovak koruna ]          2608 non-null   object
#  37  [Thai baht ]              6284 non-null   object
#  38  [Turkish lira ]           6222 non-null   float64
#  39  [US dollar ]              6284 non-null   object
#  40  [South African rand ]     6284 non-null   object
# dtypes: float64(3), object(38)
# memory usage: 2.0+ MB

# %%
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time'},
                      inplace=True)
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
exchange_rates.sort_values('Time', inplace=True)
exchange_rates.reset_index(drop=True, inplace=True)
exchange_rates.head()
# Out:
#         Time [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0 1999-01-04               1.9100              NaN               NaN
# 1 1999-01-05               1.8944              NaN               NaN
# 2 1999-01-06               1.8820              NaN               NaN
# 3 1999-01-07               1.8474              NaN               NaN
# 4 1999-01-08               1.8406              NaN               NaN
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.8004         1.6168                      NaN          0.58231
# 1             1.7965         1.6123                      NaN          0.58230
# 2             1.7711         1.6116                      NaN          0.58200
# 3             1.7602         1.6165                      NaN          0.58187
# 4             1.7643         1.6138                      NaN          0.58187
#
#   [Czech koruna ] [Danish krone ]  ... [Romanian leu ] [Russian rouble ]  \
# 0          35.107          7.4501  ...          1.3111           25.2875
# 1          34.917          7.4495  ...          1.3168           26.5876
# 2          34.850          7.4452  ...          1.3168           27.4315
# 3          34.886          7.4431  ...          1.3092           26.9876
# 4          34.938          7.4433  ...          1.3143           27.2075
#
#   [Swedish krona ] [Singapore dollar ] [Slovenian tolar ] [Slovak koruna ]  \
# 0           9.4696              1.9554           189.0450           42.991
# 1           9.4025              1.9655           188.7750           42.848
# 2           9.3050              1.9699           188.7000           42.778
# 3           9.1800              1.9436           188.8000           42.765
# 4           9.1650              1.9537           188.8400           42.560
#
#   [Thai baht ] [Turkish lira ] US_dollar  [South African rand ]
# 0      42.6799          0.3723    1.1789                 6.9358
# 1      42.5048          0.3728    1.1790                 6.7975
# 2      42.6949          0.3722    1.1743                 6.7307
# 3      42.1678          0.3701    1.1632                 6.8283
# 4      42.5590          0.3718    1.1659                 6.7855
#
# [5 rows x 41 columns]

# %%
euro_to_dollar = exchange_rates[['Time', 'US_dollar']].copy()
euro_to_dollar['US_dollar'].value_counts() # 62 '-' characters
# Out:
# -         62
# 1.2276     9
# 1.1215     8
# 1.1268     7
# 1.1305     7
#           ..
# 1.3885     1
# 1.3860     1
# 1.3877     1
# 1.4030     1
# 1.1057     1
# Name: US_dollar, Length: 3729, dtype: int64

# %%
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)
euro_to_dollar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6222 entries, 0 to 6283
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Time       6222 non-null   datetime64[ns]
#  1   US_dollar  6222 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 145.8 KB
# <ipython-input-22-acfddb10b548>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

# %%
import matplotlib.pyplot as plt


plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.show()

# %%
plt.figure(figsize=(9,6))

plt.subplot(3,2,1)
plt.plot(euro_to_dollar['Time'], euro_to_dollar['US_dollar'])
plt.title('Original values', weight='bold')

for i, rolling_mean in zip([2, 3, 4, 5, 6],
                           [7, 30, 50, 100, 365]):
    plt.subplot(3,2,i)
    plt.plot(euro_to_dollar['Time'],
             euro_to_dollar['US_dollar'].rolling(rolling_mean).mean())
    plt.title('Rolling Window:' + str(rolling_mean), weight='bold')
    
plt.tight_layout() # Auto-adjusts the padding between subplots
plt.show()

# %%
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()
euro_to_dollar.tail()
# Out:
#            Time  US_dollar  rolling_mean
# 6279 2023-04-12     1.0922      1.074353
# 6280 2023-04-13     1.1015      1.075673
# 6281 2023-04-14     1.1057      1.076917
# 6282 2023-04-17     1.0981      1.078170
# 6283 2023-04-18     1.0972      1.079360

# %%
financial_crisis = euro_to_dollar.copy(
                   )[(euro_to_dollar['Time'].dt.year >= 2006
                   ) & (euro_to_dollar['Time'].dt.year <= 2009)]
financial_crisis_7_8 = euro_to_dollar.copy(
                   )[(euro_to_dollar.Time.dt.year >= 2007
                   ) & (euro_to_dollar.Time.dt.year <= 2008)]

# %%
# Assuming 'Value' is the column for which you want to calculate the rolling mean

# For financial_crisis dataframe
financial_crisis = euro_to_dollar.copy()[
                   (euro_to_dollar['Time'].dt.year >= 2006) &
                   (euro_to_dollar['Time'].dt.year <= 2009)
                   ]

# For financial_crisis_7_8 dataframe
financial_crisis_7_8 = euro_to_dollar.copy()[
                      (euro_to_dollar.Time.dt.year >= 2007) &
                      (euro_to_dollar.Time.dt.year <= 2008)
                      ]

# %%
print(financial_crisis.head())
# Out:
#            Time  US_dollar  rolling_mean
# 1825 2006-01-02     1.1826      1.183087
# 1826 2006-01-03     1.1875      1.183300
# 1827 2006-01-04     1.2083      1.184573
# 1828 2006-01-05     1.2088      1.185613
# 1829 2006-01-06     1.2093      1.186647

# %% [markdown]
# Axes.text(x, y, s, fontdict=None, **kwargs)[source]
#
# ax.set_title{'fontsize': rcParams['axes.titlesize'],
#  'fontweight': rcParams['axes.titleweight'],
#  'color': rcParams['axes.titlecolor'],
#  'verticalalignment': 'baseline',
#  'horizontalalignment': loc}
#
# > Indented block

# %%
### Adding the FiveThirtyEight style
import matplotlib.style as style
style.use('dark_background')

### Adding the plot
fig,ax = plt.subplots(figsize=(12,6))
ax.plot(financial_crisis['Time'],
        financial_crisis['rolling_mean'],
        linewidth=1, color='#A6D785', alpha=1)

### Highlighting the 2007-2008 period
ax.plot(financial_crisis_7_8['Time'],
        financial_crisis_7_8['rolling_mean'],
        linewidth=3, color='#e23d28', alpha=.7)
ax.grid(visible=None, which='major')

ax.set_title('Housing Financial Crisis', color='grey', fontsize='25', weight='bold')

plt.show()

# %%
print(financial_crisis.columns)
# Out:
# Index(['Time', 'US_dollar', 'rolling_mean'], dtype='object')

# %%
bush_obama_trump = euro_to_dollar.copy(
                   )[(euro_to_dollar['Time'].dt.year >= 2001) & (euro_to_dollar['Time'].dt.year < 2021)]
bush = bush_obama_trump.copy(
       )[bush_obama_trump['Time'].dt.year < 2009]
obama = bush_obama_trump.copy(
       )[(bush_obama_trump['Time'].dt.year >= 2009) & (bush_obama_trump['Time'].dt.year < 2017)]
trump = bush_obama_trump.copy(
       )[(bush_obama_trump['Time'].dt.year >= 2017) & (bush_obama_trump['Time'].dt.year < 2021)]

# %%
### Adding the FiveThirtyEight style
style.use('dark_background')

### Adding the subplots
plt.figure(figsize=(12, 6))
ax1 = plt.subplot(2,3,1)
ax2 = plt.subplot(2,3,2)
ax3 = plt.subplot(2,3,3)
ax4 = plt.subplot(2,1,2)
axes = [ax1, ax2, ax3, ax4]

### Changes to all the subplots
for ax in axes:
    ax.set_ylim(0.8, 1.7)
    ax.set_yticks([1.0, 1.2, 1.4, 1.6])
    ax.set_yticklabels(['1.0', '1.2','1.4', '1.6'],
                   alpha=0.3)
    ax.grid(alpha=0.5)    
    

### Ax1: Bush
ax1.plot(bush['Time'], bush['rolling_mean'],
        color='#BF5FFF')
ax1.set_xticklabels(['', '2001', '', '2003', '', '2005', '',
                     '2007', '', '2009'],
                   alpha=0.5)
ax1.set_title('Bush', color='#BF5FFF', fontsize='15', weight='bold')


### Ax2: Obama
ax2.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax2.set_xticklabels(['', '2009', '', '2011', '', '2013', '',
                     '2015', '', '2017'],
                   alpha=0.5)
ax2.set_title('Obama', color='#ffa500', fontsize='15', weight='bold')

### Ax3: Trump
ax3.plot(trump['Time'], trump['rolling_mean'],
        color='#00B2EE')
ax3.set_xticklabels(['2017', '', '2018', '', '2019', '',
                     '2020', '', '2021'],
                   alpha=0.5)

ax3.set_title('Trump', color='#00B2EE', fontsize='15', weight='bold')


### Ax4: Bush-Obama-Trump
ax4.plot(bush['Time'], bush['rolling_mean'],
        color='#BF5FFF')
ax4.plot(obama['Time'], obama['rolling_mean'],
        color='#ffa500')
ax4.plot(trump['Time'], trump['rolling_mean'],
        color='#00B2EE')
ax4.grid(visible=None, which='major')
ax4.set_xticks([])



plt.show()
